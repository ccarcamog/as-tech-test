# %% [markdown]
# # Exploratory Data Analysis
# #### by Carlos Carcamo
#
# In this document, I will explore the data sources files for the project, to find any issue on the data. At the end of the analysis I will made a summary with all the cleaning tasks over the data.

# %%
#Import libraries to be used
import pandas as pd
import json

# %% [markdown]
# ## Profile dataset.csv
#
# Let's start extracting the dataset.csv

# %%
#Storing file into Pandas' DataFrame
df = pd.read_csv('dataset.csv', encoding='unicode_escape')
# Out:
# C:\Users\Carcac01\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (3) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# > Note: In the extraction phase, I had some troubles with file encoding. There are some characters that are not part of the utf-8 encoding, so I had to change it.

# %%
#Read df
df.head()
# Out:
#    ORDER_ID  USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 0   1000029    54650             4         3                 13
# 0   1000029    54650             4         3                 13
# 0   1000029    54650             4         3                 13
# 0   1000029    54650             4         3                 13
# 0   1000029    54650             4         3                 13
#
#                   ORDER_PRODUCT  ORDER_PROD_AISLE ORDER_SEQ
# 0  Almond Chia Granola Clusters           granola         1
# 0             Fresh Cauliflower  fresh vegetables         2
# 0            Orange Bell Pepper  fresh vegetables         3
# 0                  Veggie Chips    chips pretzels         8
# 0           Organic Gala Apples      fresh fruits         5

# %%
#number of rows and columns
df.shape
# Out:
# (1384617, 8)

# %%
#Get datatypes 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 131209 entries, 0 to 131208
# Data columns (total 6 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   ORDER_ID           131209 non-null  int64
#  1   USER_ID            131209 non-null  int64
#  2   ORDER_NUMBER       131209 non-null  int64
#  3   ORDER_DOW          131209 non-null  object
#  4   ORDER_HOUR_OF_DAY  131209 non-null  int64
#  5   ORDER_DETAIL       131209 non-null  object
# dtypes: int64(4), object(2)
# memory usage: 6.0+ MB

# %% [markdown]
# It seems that ORDER_DOW has some invalid values, lets see

# %%
df.ORDER_DOW.value_counts()
# Out:
# 0          27439
# 1          19650
# 6          18878
# 5          17389
# 2          16090
# 4          15941
# 3          15664
# 0             26
# 6             23
# 3             23
# 1             22
# 4             18
# Tuesday       16
# 2             13
# 5             12
# Friday         5
# Name: ORDER_DOW, dtype: int64

# %% [markdown]
# There are some string values, and some numbers recognized as strings. It will be neccesary to fix it.
#
# Let's explore hours column:

# %%
df.ORDER_HOUR_OF_DAY.value_counts()
# Out:
# 14    11103
# 15    11075
# 13    10711
# 12    10622
# 11    10610
# 10    10585
# 16    10495
# 17     9353
# 9      9033
# 18     7558
# 8      6343
# 19     5721
# 20     3978
# 7      3376
# 21     3050
# 22     2442
# 23     1526
# 6      1121
# 0       848
# 1       507
# 5       402
# 2       305
# 3       223
# 4       218
# 24        4
# Name: ORDER_HOUR_OF_DAY, dtype: int64

# %% [markdown]
# It seems there are 4 orders registered as 24h. As the catalog will be defined from 0 to 23, It will be necessary to fix it.
#
# Regarding to structure of the data source, it seems very obvious some transformations on ORDER_DETAIL column. We have wrapped ther some valius information, like Product Name, Aisle and Order Sequence. Also, we have all the detail from an individualk order wrapped, too. So, let's start unwraping it.
#
# Fisrt step, will be explode the field by Order Detail:

# %%
#Split df using ~ chat
df['ORDER_DETAIL_EXPLODED'] = df['ORDER_DETAIL'].str.split(pat='~')
df
# Out:
#         ORDER_ID  USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 0        1000029    54650             4         3                 13
# 1        1003104   124957            10         1                 16
# 2        1004115   110922            15         0                 14
# 3        1004231    12037             7         1                 19
# 4        1004492   196375            16         0                 13
# ...          ...      ...           ...       ...                ...
# 131204    995474   202893            17         2                 13
# 131205    997017   193337            21         5                 11
# 131206    997622     8661            38         3                  9
# 131207    998840    19932             6         2                 12
# 131208    999742   121825            10         4                 19
#
#                                              ORDER_DETAIL  \
# 0       Almond Chia Granola Clusters|granola|1~Fresh C...
# 1       Limes|fresh fruits|5~Tomato Juice|juice nectar...
# 2       Skim Milk|milk|4~Organic Stage 3 Pumpkin Cranb...
# 3       Banana|fresh fruits|3~Green Tea Bags|tea|10~Or...
# 4       Organic Sprouted English Muffin|breakfast bake...
# ...                                                   ...
# 131204  Bag of Organic Bananas|fresh fruits|1~Strawber...
# 131205  Strawberries|fresh fruits|1~15 Grain Whole Gra...
# 131206  Antiperspirant Deodorant Cool Essentials Fresh...
# 131207  Popcorn|popcorn jerky|1~Bag of Organic Bananas...
# 131208  Strawberry Preserves|spreads|3~Creamy Peanut B...
#
#                                     ORDER_DETAIL_EXPLODED
# 0       [Almond Chia Granola Clusters|granola|1, Fresh...
# 1       [Limes|fresh fruits|5, Tomato Juice|juice nect...
# 2       [Skim Milk|milk|4, Organic Stage 3 Pumpkin Cra...
# 3       [Banana|fresh fruits|3, Green Tea Bags|tea|10,...
# 4       [Organic Sprouted English Muffin|breakfast bak...
# ...                                                   ...
# 131204  [Bag of Organic Bananas|fresh fruits|1, Strawb...
# 131205  [Strawberries|fresh fruits|1, 15 Grain Whole G...
# 131206  [Antiperspirant Deodorant Cool Essentials Fres...
# 131207  [Popcorn|popcorn jerky|1, Bag of Organic Banan...
# 131208  [Strawberry Preserves|spreads|3, Creamy Peanut...
#
# [131209 rows x 7 columns]

# %%
#Explode Dataframe
df = df.explode('ORDER_DETAIL_EXPLODED')
df
# Out:
#         ORDER_ID  USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# ...          ...      ...           ...       ...                ...
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
#
#                                              ORDER_DETAIL  \
# 0       Almond Chia Granola Clusters|granola|1~Fresh C...
# 0       Almond Chia Granola Clusters|granola|1~Fresh C...
# 0       Almond Chia Granola Clusters|granola|1~Fresh C...
# 0       Almond Chia Granola Clusters|granola|1~Fresh C...
# 0       Almond Chia Granola Clusters|granola|1~Fresh C...
# ...                                                   ...
# 131208  Strawberry Preserves|spreads|3~Creamy Peanut B...
# 131208  Strawberry Preserves|spreads|3~Creamy Peanut B...
# 131208  Strawberry Preserves|spreads|3~Creamy Peanut B...
# 131208  Strawberry Preserves|spreads|3~Creamy Peanut B...
# 131208  Strawberry Preserves|spreads|3~Creamy Peanut B...
#
#                                     ORDER_DETAIL_EXPLODED
# 0                  Almond Chia Granola Clusters|granola|1
# 0                    Fresh Cauliflower|fresh vegetables|2
# 0                   Orange Bell Pepper|fresh vegetables|3
# 0                           Veggie Chips|chips pretzels|8
# 0                      Organic Gala Apples|fresh fruits|5
# ...                                                   ...
# 131208             Classic Potato Chips|chips pretzels|11
# 131208               Mozzarella Fresca|packaged cheese|12
# 131208                Salted Butter Half Sticks|butter|13
# 131208  Bathroom Tissue Softness & Strength, Double Ro...
# 131208     Eggo Chocolate Chip Waffles|frozen breakfast|1
#
# [1384617 rows x 7 columns]

# %%
#Drop ORDER_DETAIL column, as it was exploded
df = df.drop(['ORDER_DETAIL'], axis=1)
df
# Out:
#         ORDER_ID  USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# ...          ...      ...           ...       ...                ...
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
#
#                                     ORDER_DETAIL_EXPLODED
# 0                  Almond Chia Granola Clusters|granola|1
# 0                    Fresh Cauliflower|fresh vegetables|2
# 0                   Orange Bell Pepper|fresh vegetables|3
# 0                           Veggie Chips|chips pretzels|8
# 0                      Organic Gala Apples|fresh fruits|5
# ...                                                   ...
# 131208             Classic Potato Chips|chips pretzels|11
# 131208               Mozzarella Fresca|packaged cheese|12
# 131208                Salted Butter Half Sticks|butter|13
# 131208  Bathroom Tissue Softness & Strength, Double Ro...
# 131208     Eggo Chocolate Chip Waffles|frozen breakfast|1
#
# [1384617 rows x 6 columns]

# %% [markdown]
# Now, its time to split the column into 3 new columns:

# %%
#Split by | char
df[['ORDER_PRODUCT','ORDER_PROD_AISLE','ORDER_SEQ']] = df['ORDER_DETAIL_EXPLODED'].str.split(pat='|', expand = True)
df
# Out:
#         ORDER_ID  USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# ...          ...      ...           ...       ...                ...
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
#
#                                     ORDER_DETAIL_EXPLODED  \
# 0                  Almond Chia Granola Clusters|granola|1
# 0                    Fresh Cauliflower|fresh vegetables|2
# 0                   Orange Bell Pepper|fresh vegetables|3
# 0                           Veggie Chips|chips pretzels|8
# 0                      Organic Gala Apples|fresh fruits|5
# ...                                                   ...
# 131208             Classic Potato Chips|chips pretzels|11
# 131208               Mozzarella Fresca|packaged cheese|12
# 131208                Salted Butter Half Sticks|butter|13
# 131208  Bathroom Tissue Softness & Strength, Double Ro...
# 131208     Eggo Chocolate Chip Waffles|frozen breakfast|1
#
#                                             ORDER_PRODUCT  ORDER_PROD_AISLE  \
# 0                            Almond Chia Granola Clusters           granola
# 0                                       Fresh Cauliflower  fresh vegetables
# 0                                      Orange Bell Pepper  fresh vegetables
# 0                                            Veggie Chips    chips pretzels
# 0                                     Organic Gala Apples      fresh fruits
# ...                                                   ...               ...
# 131208                               Classic Potato Chips    chips pretzels
# 131208                                  Mozzarella Fresca   packaged cheese
# 131208                          Salted Butter Half Sticks            butter
# 131208  Bathroom Tissue Softness & Strength, Double Rolls       paper goods
# 131208                        Eggo Chocolate Chip Waffles  frozen breakfast
#
#        ORDER_SEQ
# 0              1
# 0              2
# 0              3
# 0              8
# 0              5
# ...          ...
# 131208        11
# 131208        12
# 131208        13
# 131208         4
# 131208         1
#
# [1384617 rows x 9 columns]

# %%
df = df.drop(['ORDER_DETAIL_EXPLODED'], axis=1)
df
# Out:
#         ORDER_ID  USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# ...          ...      ...           ...       ...                ...
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
#
#                                             ORDER_PRODUCT  ORDER_PROD_AISLE  \
# 0                            Almond Chia Granola Clusters           granola
# 0                                       Fresh Cauliflower  fresh vegetables
# 0                                      Orange Bell Pepper  fresh vegetables
# 0                                            Veggie Chips    chips pretzels
# 0                                     Organic Gala Apples      fresh fruits
# ...                                                   ...               ...
# 131208                               Classic Potato Chips    chips pretzels
# 131208                                  Mozzarella Fresca   packaged cheese
# 131208                          Salted Butter Half Sticks            butter
# 131208  Bathroom Tissue Softness & Strength, Double Rolls       paper goods
# 131208                        Eggo Chocolate Chip Waffles  frozen breakfast
#
#        ORDER_SEQ
# 0              1
# 0              2
# 0              3
# 0              8
# 0              5
# ...          ...
# 131208        11
# 131208        12
# 131208        13
# 131208         4
# 131208         1
#
# [1384617 rows x 8 columns]

# %%
df
# Out:
#         ORDER_ID  USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# 0        1000029    54650             4         3                 13
# ...          ...      ...           ...       ...                ...
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
# 131208    999742   121825            10         4                 19
#
#                                             ORDER_PRODUCT  ORDER_PROD_AISLE  \
# 0                            Almond Chia Granola Clusters           granola
# 0                                       Fresh Cauliflower  fresh vegetables
# 0                                      Orange Bell Pepper  fresh vegetables
# 0                                            Veggie Chips    chips pretzels
# 0                                     Organic Gala Apples      fresh fruits
# ...                                                   ...               ...
# 131208                               Classic Potato Chips    chips pretzels
# 131208                                  Mozzarella Fresca   packaged cheese
# 131208                          Salted Butter Half Sticks            butter
# 131208  Bathroom Tissue Softness & Strength, Double Rolls       paper goods
# 131208                        Eggo Chocolate Chip Waffles  frozen breakfast
#
#        ORDER_SEQ
# 0              1
# 0              2
# 0              3
# 0              8
# 0              5
# ...          ...
# 131208        11
# 131208        12
# 131208        13
# 131208         4
# 131208         1
#
# [1384617 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1384617 entries, 0 to 131208
# Data columns (total 8 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   ORDER_ID           1384617 non-null  int64
#  1   USER_ID            1384617 non-null  int64
#  2   ORDER_NUMBER       1384617 non-null  int64
#  3   ORDER_DOW          1384617 non-null  object
#  4   ORDER_HOUR_OF_DAY  1384617 non-null  int64
#  5   ORDER_PRODUCT      1384617 non-null  object
#  6   ORDER_PROD_AISLE   1384617 non-null  object
#  7   ORDER_SEQ          1384617 non-null  object
# dtypes: int64(4), object(4)
# memory usage: 95.1+ MB

# %% [markdown]
# Let's continue grouping the order by ORDER_ID, just to find if is there any outlier number of products for an specific order:

# %%
grouped_df = df.groupby(['ORDER_ID'])['ORDER_ID'].agg([len])
grouped_df.sort_values(by='len', ascending=False)
# Out:
#           len
# ORDER_ID
# 1395075    80
# 2813632    80
# 949182     77
# 2869702    76
# 341238     76
# ...       ...
# 1144944     1
# 1144765     1
# 1144608     1
# 1144038     1
# 3214874     1
#
# [131209 rows x 1 columns]

# %% [markdown]
# An order with 80 products can be considered as normal, but let's explore that particular case:

# %%
df[df['ORDER_ID'] == 1395075].sort_values(by='ORDER_SEQ')
# Out:
#        ORDER_ID  USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 66256   1395075   197541            13         1                 14
# 66256   1395075   197541            13         1                 14
# 66256   1395075   197541            13         1                 14
# 66256   1395075   197541            13         1                 14
# 66256   1395075   197541            13         1                 14
# ...         ...      ...           ...       ...                ...
# 66256   1395075   197541            13         1                 14
# 66256   1395075   197541            13         1                 14
# 66256   1395075   197541            13         1                 14
# 66256   1395075   197541            13         1                 14
# 66256   1395075   197541            13         1                 14
#
#                                            ORDER_PRODUCT  \
# 66256                  Original Liquid Laundry Detergent
# 66256                              Hemorrhoidal Ointment
# 66256                  Double Zipper Gallon Freezer Bags
# 66256                                 Quart Storage Bags
# 66256            Reduced Fat Creamy Peanut Butter Spread
# ...                                                  ...
# 66256                       Organic Baby Bella Mushrooms
# 66256                                    Organic Avocado
# 66256           Shower Tub & Tile Cleaner with Oxy Clean
# 66256                          Mixed Nuts Lightly Salted
# 66256  Fabric Softener Dryer Sheet Outdoor Fresh 240C...
#
#                  ORDER_PROD_AISLE ORDER_SEQ
# 66256                     laundry         1
# 66256                   digestion        10
# 66256                food storage        11
# 66256                food storage        12
# 66256                     spreads        13
# ...                           ...       ...
# 66256  packaged vegetables fruits        78
# 66256                fresh fruits        79
# 66256           cleaning products         8
# 66256      nuts seeds dried fruit        80
# 66256                     laundry         9
#
# [80 rows x 8 columns]

# %% [markdown]
# Find duplicated rows:

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [ORDER_ID, USER_ID, ORDER_NUMBER, ORDER_DOW, ORDER_HOUR_OF_DAY, ORDER_PRODUCT, ORDER_PROD_AISLE, ORDER_SEQ]
# Index: []

# %% [markdown]
# No duplicated rows were found.
#
# now, let's check if the corelation between ORDER_ID and ORder_NUM is the same

# %%
grouped_df = df.groupby(['ORDER_ID','ORDER_NUMBER'])['ORDER_ID'].agg([len])
##grouped_df.sort_values(by='len', ascending=False)
grouped_df
# Out:
#                        len
# ORDER_ID ORDER_NUMBER
# 1        4               8
# 36       23              8
# 38       6               9
# 96       7               7
# 98       41             49
# ...                    ...
# 3421049  4               6
# 3421056  13              5
# 3421058  20              8
# 3421063  30              4
# 3421070  15              3
#
# [131209 rows x 1 columns]

# %% [markdown]
# ## Profile product.json file
#
# Now, its time to check the json file:

# %%
with open('products.json','r',encoding='utf-8') as json_file:
    data =json.load(json_file)

    #Navigate into json file, to find the items element
list_results = data["results"]
dict_products = list_results[0]
items_list = dict_products["items"]

#Load json into Pandas' Dataframe
df_json = pd.DataFrame(items_list, columns = ['product_name','aisle','department'])

df_json
# Out:
#                                             product_name  \
# 0                             Chocolate Sandwich Cookies
# 1                                       All-Seasons Salt
# 2                   Robust Golden Unsweetened Oolong Tea
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...
# 4                              Green Chile Anytime Sauce
# ...                                                  ...
# 49683          Vodka, Triple Distilled, Twist of Vanilla
# 49684                 En Croute Roast Hazelnut Cranberry
# 49685                                   Artisan Baguette
# 49686         Smartblend Healthy Metabolism Dry Cat Food
# 49687                             Fresh Foaming Cleanser
#
#                             aisle     department
# 0                   cookies cakes         snacks
# 1               spices seasonings         pantry
# 2                             tea      beverages
# 3                    frozen meals         frozen
# 4      marinades meat preparation         pantry
# ...                           ...            ...
# 49683                     spirits        alcohol
# 49684     frozen vegan vegetarian         frozen
# 49685                       bread         bakery
# 49686               cat food care           pets
# 49687                 facial care  personal care
#
# [49688 rows x 3 columns]

# %%
df_json['aisle'].unique()
# Out:
# array(['cookies cakes', 'spices seasonings', 'tea', 'frozen meals',
#        'marinades meat preparation', 'cold flu allergy', 'juice nectars',
#        'frozen produce', 'yogurt', 'water seltzer sparkling water',
#        'refrigerated', 'frozen dessert', 'dish detergents',
#        'diapers wipes', 'ice cream toppings', 'poultry counter',
#        'frozen pizza', 'grains rice dried goods', 'dog food care',
#        'oral hygiene', 'packaged poultry', 'vitamins supplements',
#        'energy granola bars', 'cat food care', 'body lotions soap',
#        'cereal', 'canned jarred vegetables', 'packaged vegetables fruits',
#        'chips pretzels', 'dry pasta', 'hot dogs bacon sausage',
#        'soup broth bouillon', 'missing', 'energy sports drinks',
#        'crackers', 'fresh vegetables', 'frozen breads doughs',
#        'asian foods', 'more household', 'tofu meat alternatives',
#        'doughs gelatins bake mixes', 'hair care',
#        'specialty wines champagnes', 'popcorn jerky',
#        'plates bowls cups flatware', 'tortillas flat bread',
#        'fruit vegetable snacks', 'pasta sauce', 'lunch meat',
#        'baby food formula', 'salad dressing toppings', 'spreads',
#        'hot cereal pancake mixes', 'coffee', 'soft drinks',
#        'protein meal replacements', 'fresh pasta', 'canned meat seafood',
#        'oils vinegars', 'packaged meat', 'other', 'baking supplies decor',
#        'specialty cheeses', 'bread', 'kitchen supplies',
#        'preserved dips spreads', 'prepared meals', 'laundry', 'digestion',
#        'breakfast bakery', 'frozen meat seafood', 'white wines',
#        'packaged cheese', 'honeys syrups nectars', 'candy chocolate',
#        'first aid', 'instant foods', 'other creams cheeses',
#        'ice cream ice', 'skin care', 'soy lactosefree', 'fresh fruits',
#        'fresh dips tapenades', 'beauty', 'soap',
#        'frozen appetizers sides', 'mint gum', 'fresh herbs',
#        'frozen breakfast', 'baking ingredients', 'facial care',
#        'meat counter', 'frozen vegan vegetarian', 'canned meals beans',
#        'feminine care', 'kosher foods', 'prepared soups salads',
#        'bakery desserts', 'baby accessories', 'cleaning products',
#        'spirits', 'nuts seeds dried fruit', 'condiments',
#        'pickled goods olives', 'food storage', 'eye ear care',
#        'deodorants', 'air fresheners candles', 'milk', 'latino foods',
#        'beers coolers', 'cocoa drink mixes', 'breakfast bars pastries',
#        'muscles joints pain relief', 'cream', 'red wines',
#        'bulk grains rice dried goods', 'buns rolls',
#        'trail mix snack mix', 'granola', 'packaged seafood',
#        'shave needs', 'butter', 'paper goods', 'baby bath body care',
#        'trash bags liners', 'canned fruit applesauce',
#        'bulk dried fruits vegetables', 'seafood counter',
#        'refrigerated pudding desserts', 'frozen juice', 'eggs',
#        'packaged produce', 'indian foods'], dtype=object)

# %%
grouped_df = df_json.groupby(['aisle'])['aisle'].agg([len])
grouped_df.sort_values(by='len', ascending=False)
# Out:
#                                len
# aisle
# missing                       1258
# candy chocolate               1246
# ice cream ice                 1091
# vitamins supplements          1038
# yogurt                        1026
# ...                            ...
# frozen juice                    47
# baby accessories                44
# packaged produce                32
# bulk grains rice dried goods    26
# bulk dried fruits vegetables    12
#
# [134 rows x 1 columns]

# %% [markdown]
# It seems there are a lot of missing values for aisle. Those values must be sent to the client/business for checks and to correct the data. For this moment, I will treat them as correct data, as I can't define the correct aisle, and also, I can't just erase the data as I will be losig a significant part of the products.
#
# Let's check the department field:

# %%
grouped_df = df_json.groupby(['department'])['department'].agg([len])
grouped_df.sort_values(by='len', ascending=False)
# Out:
#                   len
# department
# personal care    6563
# snacks           6264
# pantry           5371
# beverages        4365
# frozen           4007
# dairy eggs       3449
# household        3085
# canned goods     2092
# dry goods pasta  1858
# produce          1684
# bakery           1516
# deli             1322
# missing          1258
# international    1139
# breakfast        1115
# babies           1081
# alcohol          1054
# pets              972
# meat seafood      907
# other             548
# bulk               38

# %% [markdown]
# Is a similar issue. I will continue treat them as correct values.
#
# Now, I will check for duplicity:

# %%
df_json[df_json.duplicated()]
# Out:
# Empty DataFrame
# Columns: [product_name, aisle, department]
# Index: []

# %% [markdown]
# There are no duplicates on json file.

# %%
df_json[df_json.product_name.str.contains("Microwavable Cut Resistant Plates")]
# Out:
#                                   product_name                       aisle  \
# 28030  8.5\" Microwavable Cut Resistant Plates  plates bowls cups flatware
#
#       department
# 28030  household

# %%
df_json['product_name'] = df_json['product_name'].str.replace('\\','')

# %%
df_json[df_json.product_name.str.contains("Organic Chocolate Cake")]
# Out:
#                      product_name                       aisle department
# 9928    6" Organic Chocolate Cake             bakery desserts     bakery
# 13799     Organic Chocolate Cakes              frozen dessert     frozen
# 22416  Organic Chocolate Cake Mix  doughs gelatins bake mixes     pantry

# %%
inner_join_df = pd.merge(df,df_json,left_on='ORDER_PRODUCT', right_on='product_name')
inner_join_df
# Out:
#          ORDER_ID  USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 0         1000029    54650             4         3                 13
# 1          605562    50291            10         2                 15
# 2         1314091   152359            21         0                 16
# 3         1462113    55876             9         1                 14
# 4           83463   177131            15         2                 16
# ...           ...      ...           ...       ...                ...
# 1383309    960112    89556             5         3                 11
# 1383310    963719   117430             4         6                 16
# 1383311    963719   117430             4         6                 16
# 1383312    968144   175649             5         6                 18
# 1383313    997622     8661            38         3                  9
#
#                                              ORDER_PRODUCT  \
# 0                             Almond Chia Granola Clusters
# 1                             Almond Chia Granola Clusters
# 2                             Almond Chia Granola Clusters
# 3                             Almond Chia Granola Clusters
# 4                             Almond Chia Granola Clusters
# ...                                                    ...
# 1383309  Active Blueberry Pomegranate Clear Nutritional...
# 1383310                        Chocolate Chip Heart Thrive
# 1383311                       Skinner's Raisin Bran Cereal
# 1383312                                    Rainbow Carrots
# 1383313                   Sugar Free Energy Drink Original
#
#                   ORDER_PROD_AISLE ORDER_SEQ  \
# 0                          granola         1
# 1                          granola        13
# 2                          granola         9
# 3                          granola         4
# 4                          granola        17
# ...                            ...       ...
# 1383309  protein meal replacements         1
# 1383310            bakery desserts         5
# 1383311                     cereal        10
# 1383312           fresh vegetables        10
# 1383313       energy sports drinks         3
#
#                                               product_name  \
# 0                             Almond Chia Granola Clusters
# 1                             Almond Chia Granola Clusters
# 2                             Almond Chia Granola Clusters
# 3                             Almond Chia Granola Clusters
# 4                             Almond Chia Granola Clusters
# ...                                                    ...
# 1383309  Active Blueberry Pomegranate Clear Nutritional...
# 1383310                        Chocolate Chip Heart Thrive
# 1383311                       Skinner's Raisin Bran Cereal
# 1383312                                    Rainbow Carrots
# 1383313                   Sugar Free Energy Drink Original
#
#                              aisle     department
# 0                          granola      breakfast
# 1                          granola      breakfast
# 2                          granola      breakfast
# 3                          granola      breakfast
# 4                          granola      breakfast
# ...                            ...            ...
# 1383309  protein meal replacements  personal care
# 1383310            bakery desserts         bakery
# 1383311                     cereal      breakfast
# 1383312           fresh vegetables        produce
# 1383313       energy sports drinks      beverages
#
# [1383314 rows x 11 columns]

# %%
df.shape[0]-inner_join_df.shape[0]
# Out:
# 1303

# %%
inner_join_df[inner_join_df['ORDER_PROD_AISLE']!=inner_join_df['aisle']]
# Out:
# Empty DataFrame
# Columns: [ORDER_ID, USER_ID, ORDER_NUMBER, ORDER_DOW, ORDER_HOUR_OF_DAY, ORDER_PRODUCT, ORDER_PROD_AISLE, ORDER_SEQ, product_name, aisle, department]
# Index: []

# %%
outer_join_df = pd.merge(df,df_json,left_on='ORDER_PRODUCT', right_on='product_name', how='outer',indicator=True)
outer_join_df = outer_join_df[outer_join_df['product_name'].isnull()]
outer_join_df
# Out:
#           ORDER_ID   USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 839446   1440136.0   81449.0           6.0         6               18.0
# 839447   1683797.0  192346.0           6.0         5               12.0
# 839448   2288931.0   76181.0           7.0         5               15.0
# 839449     36580.0  112691.0          41.0         0               14.0
# 839450    420767.0  112528.0           6.0         4               16.0
# ...            ...       ...           ...       ...                ...
# 1381236  2710094.0  116856.0           5.0         0               19.0
# 1382422   250181.0  162884.0           5.0         6               12.0
# 1382423   695462.0  119586.0           7.0         6               15.0
# 1382424   218685.0   46783.0           8.0         6               18.0
# 1382944  3351158.0   24722.0           6.0         4               21.0
#
#                                              ORDER_PRODUCT  \
# 839446   Flip Low-Fat Almond Coco Loco Lowfat Greek Yo...
# 839447   Flip Low-Fat Almond Coco Loco Lowfat Greek Yo...
# 839448   Flip Low-Fat Almond Coco Loco Lowfat Greek Yo...
# 839449   Flip Low-Fat Almond Coco Loco Lowfat Greek Yo...
# 839450   Flip Low-Fat Almond Coco Loco Lowfat Greek Yo...
# ...                                                    ...
# 1381236  Infusions Ultra Downy® Infusions Lavender Ser...
# 1382422                          Kickin BBQ Chopped Salad
# 1382423                          Kickin BBQ Chopped Salad
# 1382424                          Kickin BBQ Chopped Salad
# 1382944   D-Vi-Sol Vitamin D Supplement Drops for Infants
#
#                    ORDER_PROD_AISLE ORDER_SEQ product_name aisle department  \
# 839446                       yogurt         6          NaN   NaN        NaN
# 839447                       yogurt        28          NaN   NaN        NaN
# 839448                       yogurt        10          NaN   NaN        NaN
# 839449                       yogurt        15          NaN   NaN        NaN
# 839450                       yogurt         2          NaN   NaN        NaN
# ...                             ...       ...          ...   ...        ...
# 1381236                     laundry         7          NaN   NaN        NaN
# 1382422  packaged vegetables fruits         9          NaN   NaN        NaN
# 1382423  packaged vegetables fruits         4          NaN   NaN        NaN
# 1382424  packaged vegetables fruits         2          NaN   NaN        NaN
# 1382944        vitamins supplements         2          NaN   NaN        NaN
#
#             _merge
# 839446   left_only
# 839447   left_only
# 839448   left_only
# 839449   left_only
# 839450   left_only
# ...            ...
# 1381236  left_only
# 1382422  left_only
# 1382423  left_only
# 1382424  left_only
# 1382944  left_only
#
# [1303 rows x 12 columns]

# %%
df_json[df_json.product_name.str.contains("Low-Fat Almond")]
# Out:
#                                             product_name   aisle  department
# 32330  Flip™ Low-Fat Almond Coco Loco Lowfat Greek Yo...  yogurt  dairy eggs

# %%
outer_join_df = pd.merge(df,df_json,left_on='ORDER_PRODUCT', right_on='product_name', how='outer',indicator=True)
outer_join_df = outer_join_df[outer_join_df['ORDER_PRODUCT'].isnull()]
outer_join_df
# Out:
#          ORDER_ID  USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 1384617       NaN      NaN           NaN       NaN                NaN
# 1384618       NaN      NaN           NaN       NaN                NaN
# 1384619       NaN      NaN           NaN       NaN                NaN
# 1384620       NaN      NaN           NaN       NaN                NaN
# 1384621       NaN      NaN           NaN       NaN                NaN
# ...           ...      ...           ...       ...                ...
# 1395231       NaN      NaN           NaN       NaN                NaN
# 1395232       NaN      NaN           NaN       NaN                NaN
# 1395233       NaN      NaN           NaN       NaN                NaN
# 1395234       NaN      NaN           NaN       NaN                NaN
# 1395235       NaN      NaN           NaN       NaN                NaN
#
#         ORDER_PRODUCT ORDER_PROD_AISLE ORDER_SEQ  \
# 1384617           NaN              NaN       NaN
# 1384618           NaN              NaN       NaN
# 1384619           NaN              NaN       NaN
# 1384620           NaN              NaN       NaN
# 1384621           NaN              NaN       NaN
# ...               ...              ...       ...
# 1395231           NaN              NaN       NaN
# 1395232           NaN              NaN       NaN
# 1395233           NaN              NaN       NaN
# 1395234           NaN              NaN       NaN
# 1395235           NaN              NaN       NaN
#
#                                               product_name  \
# 1384617                                       Dry Nose Oil
# 1384618                                  Rendered Duck Fat
# 1384619   Gluten Free Quinoa Three Cheese & Mushroom Blend
# 1384620     Pomegranate Cranberry & Aloe Vera Enrich Drink
# 1384621  Tri-Vi-Sol® Vitamins A-C-and D Supplement Drop...
# ...                                                    ...
# 1395231                      Ginger Snaps Snacking Cookies
# 1395232                                   K Cup Dark Blend
# 1395233              Stone Baked Multi Grain Artisan Rolls
# 1395234          Vodka, Triple Distilled, Twist of Vanilla
# 1395235                 En Croute Roast Hazelnut Cranberry
#
#                            aisle       department      _merge
# 1384617         cold flu allergy    personal care  right_only
# 1384618          poultry counter     meat seafood  right_only
# 1384619  grains rice dried goods  dry goods pasta  right_only
# 1384620            juice nectars        beverages  right_only
# 1384621     vitamins supplements    personal care  right_only
# ...                          ...              ...         ...
# 1395231            cookies cakes           snacks  right_only
# 1395232                  missing          missing  right_only
# 1395233  frozen appetizers sides           frozen  right_only
# 1395234                  spirits          alcohol  right_only
# 1395235  frozen vegan vegetarian           frozen  right_only
#
# [10619 rows x 12 columns]

# %%
outer_join_df = pd.merge(df,df_json,left_on='ORDER_PRODUCT', right_on='product_name', how='outer',indicator=True)
outer_join_df = outer_join_df[outer_join_df['ORDER_PRODUCT'].isnull()]
outer_join_df[outer_join_df['aisle']=='missing']
# Out:
#          ORDER_ID  USER_ID  ORDER_NUMBER ORDER_DOW  ORDER_HOUR_OF_DAY  \
# 1384686       NaN      NaN           NaN       NaN                NaN
# 1384691       NaN      NaN           NaN       NaN                NaN
# 1384693       NaN      NaN           NaN       NaN                NaN
# 1384719       NaN      NaN           NaN       NaN                NaN
# 1384722       NaN      NaN           NaN       NaN                NaN
# ...           ...      ...           ...       ...                ...
# 1395171       NaN      NaN           NaN       NaN                NaN
# 1395185       NaN      NaN           NaN       NaN                NaN
# 1395197       NaN      NaN           NaN       NaN                NaN
# 1395206       NaN      NaN           NaN       NaN                NaN
# 1395232       NaN      NaN           NaN       NaN                NaN
#
#         ORDER_PRODUCT ORDER_PROD_AISLE ORDER_SEQ  \
# 1384686           NaN              NaN       NaN
# 1384691           NaN              NaN       NaN
# 1384693           NaN              NaN       NaN
# 1384719           NaN              NaN       NaN
# 1384722           NaN              NaN       NaN
# ...               ...              ...       ...
# 1395171           NaN              NaN       NaN
# 1395185           NaN              NaN       NaN
# 1395197           NaN              NaN       NaN
# 1395206           NaN              NaN       NaN
# 1395232           NaN              NaN       NaN
#
#                                           product_name    aisle department  \
# 1384686     Classics Baby Binks Easter Chocolate Bunny  missing    missing
# 1384691            Strawberry Cheesecake Nonfat Yogurt  missing    missing
# 1384693                  Crossovers Olive Thyme Almond  missing    missing
# 1384719                Bake & Break Cheese Garlic Loaf  missing    missing
# 1384722                       Traditional Tartar Sauce  missing    missing
# ...                                                ...      ...        ...
# 1395171                           Cinnamon Coffee Cake  missing    missing
# 1395185  Black Tea With Vanilla Flavor In Pyramid Bags  missing    missing
# 1395197                       Custard Caramel Sea Salt  missing    missing
# 1395206                 Chocolate Vanilla Malt Custard  missing    missing
# 1395232                               K Cup Dark Blend  missing    missing
#
#              _merge
# 1384686  right_only
# 1384691  right_only
# 1384693  right_only
# 1384719  right_only
# 1384722  right_only
# ...             ...
# 1395171  right_only
# 1395185  right_only
# 1395197  right_only
# 1395206  right_only
# 1395232  right_only
#
# [355 rows x 12 columns]

# %% [markdown]
# ## Changes proposed for dataset.csv
#
# #### Data changes
# - Replace string values on ``ORDER_DOW`` column
# - Replace "24" value for "0" on ``ORDER_HOUR_OF_DAY`` column
# - Take in count encoding for special characters
# - In the extraction phase,I have encountered some products with "?" character. I had to replace it to continue with the join with products
#
# #### Data Structure changes
# - Explode ``ORDER_DETAIL`` column by '~' character
# - Split exploded ``ORDER_DETAIL`` column by '|' character
#
# ## Changes proposed for product.json
#
# #### Data changes
# - Remove '\\' from product_name column
# - Take in count "missing" value for ``aisle`` and ``department`` columns
# - Take in count encoding for special characters
#
# #### Data Structure changes
# - Take in count there is no unique key for the structure. Joins with order must be done on ``product_name`` column
